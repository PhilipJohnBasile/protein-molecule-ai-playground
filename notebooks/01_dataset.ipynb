# %% [markdown]
# # Dataset Overview
# Exploratory look at the curated kinase activity dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_parquet('../data/clean/train.parquet')
df.head()
# Out:
#     chembl_id                                        smiles   target_id  \
# 0   CHEMBL941    CC1=CC=C(C=C1)NC(=O)C2=NC3=CC=CC=C3N2CCCCC  CHEMBL1862
# 1  CHEMBL1128    COc1ccc(-c2ccc(NC(=O)Nc3ccc(cc3)OC)cc2)nc1  CHEMBL2971
# 2  CHEMBL1427  COc1ccc2c(c1)nc(Nc3ccc(NC(=O)C)cc3)n2CCN(C)C   CHEMBL364
# 3  CHEMBL1428       COc1cccc2c1nc(Nc3ccc(NC(=O)NCCN)cc3)n2C   CHEMBL203
# 4  CHEMBL1286      CC(C)c1ccc(cc1)Nc2ncnc3ccc(NC(=O)NC)cc23  CHEMBL2147
#
#    target_seq_len  pChEMBL       qed     logp  sa_score
# 0            1130      7.6  0.663683  4.78722  2.193147
# 1             766      7.2  0.715539  4.40980  2.193147
# 2            1255      7.9  0.670347  3.30850  2.193147
# 3            1210      7.3  0.543833  2.40570  2.193147
# 4            1356      7.0  0.665859  4.24810  2.193147

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
sns.histplot(df['pChEMBL'], ax=axes[0], kde=True)
axes[0].set_title('pChEMBL distribution')
sns.countplot(y=df['target_id'], ax=axes[1])
axes[1].set_title('Target counts')
plt.tight_layout()
